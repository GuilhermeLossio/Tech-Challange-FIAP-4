# %% [markdown]
# # 04 - Model Evaluation
#
# Notebook skeleton aligned with the evaluation stage described in `README.md`.

# %% [markdown]
# ## Goals
#
# - evaluate regression quality with MAE, RMSE, and MAPE
# - compare validation and test behavior
# - compare baseline and enriched variants
# - add forecast vs actual charts and residual analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def evaluate(y_true: np.ndarray, y_pred: np.ndarray) -> dict:
    mae = np.mean(np.abs(y_true - y_pred))
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return {"MAE": mae, "RMSE": rmse, "MAPE": mape}

# %%
# Expected inputs:
# y_test, y_pred_baseline, y_pred_enriched

# baseline_metrics = evaluate(y_test, y_pred_baseline)
# enriched_metrics = evaluate(y_test, y_pred_enriched)
# pd.DataFrame([baseline_metrics, enriched_metrics], index=["baseline", "enriched"])

# %%
# Example plot scaffold
# plt.figure(figsize=(12, 4))
# plt.plot(y_test, label="actual")
# plt.plot(y_pred_baseline, label="baseline")
# plt.plot(y_pred_enriched, label="enriched")
# plt.legend()
# plt.title("Forecast vs actual")
# plt.show()

# %% [markdown]
# ## Your Steps
#
# Add here the metrics, plots, and interpretation you want to keep in the final project report.
