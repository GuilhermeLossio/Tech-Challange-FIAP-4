# %% [markdown]
# # 03 - LSTM Training
#
# Notebook skeleton aligned with the training stage described in `README.md`.

# %% [markdown]
# ## Goals
#
# - define the baseline LSTM architecture
# - configure callbacks and checkpoints
# - train the baseline or enriched model
# - capture history for later evaluation

# %%
from pathlib import Path

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
MODELS_DIR = PROJECT_ROOT / "models"
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# %%
def build_model(input_shape):
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(64, return_sequences=False),
        Dropout(0.2),
        Dense(32, activation="relu"),
        Dense(1),
    ])
    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model

# %%
MODEL_PATH = MODELS_DIR / "lstm_nvda.keras"

callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ModelCheckpoint(MODEL_PATH, save_best_only=True),
]

MODEL_PATH

# %%
# Expected inputs from the preprocessing notebook:
# X_train, y_train, X_val, y_val

# model = build_model(input_shape=(60, 1))
# history = model.fit(
#     X_train,
#     y_train,
#     validation_data=(X_val, y_val),
#     epochs=100,
#     batch_size=32,
#     callbacks=callbacks,
#     verbose=1,
# )

# %% [markdown]
# ## Your Steps
#
# Document here:
# - baseline vs enriched setup
# - checkpoint strategy
# - training duration
# - hardware/runtime notes
